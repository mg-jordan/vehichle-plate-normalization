# %%
from iraqi_plate import IraqiPlateService

svc = IraqiPlateService()

print(svc.normalize_plate("A22153").canonical)
# expected: 22A153

print(svc.normalize_plate("ا22153").canonical)
# expected: 22ا153

print(svc.equals("A22153", "22A153"))
# True
# Out:
# 22A153
# 22ا153
# True
